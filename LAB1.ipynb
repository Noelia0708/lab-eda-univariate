# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %% [markdown]
# #### Ejercicio 1

# %%
df = pd.read_csv("C:/Users/noeli/Desktop/amz_uk_price_prediction_dataset.csv")

# %%
frequency_table = df['category'].value_counts().head(5)

# %%
frequency_table
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Name: count, dtype: int64

# %%
sns.barplot(x=frequency_table.index, y=frequency_table.values, palette="Set3")
# Out:
# C:\Users\noeli\AppData\Local\Temp\ipykernel_2420\4104756953.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequency_table.index, y=frequency_table.values, palette="Set3")
# <Axes: xlabel='category'>

# %%
frequency_table2 = df['category'].value_counts(normalize=True).head(3)

# %%
frequency_table2.plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set3"))
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# #### Ejercicio 2

# %%
mean_price = df['price'].mean()
median_price = df['price'].median()
mode_price = df['price'].mode()[0]

mean_price, median_price, mode_price
# Out:
# (np.float64(89.24380943923661), np.float64(19.09), np.float64(9.99))

# %%
variance_price = df['price'].var()
std_dev_price = df['price'].std()

variance_price, std_dev_price 

#Son productos muy variados ya que tenemos mucha desviacion y hay una varianza enorme
# Out:
# (np.float64(119445.48532254901), np.float64(345.60886175349873))

# %%
sns.histplot(df['price'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# #### es imposible poder leer esto ya que todo se centra en productos de precio mas bajo teniendo unos pocos con mas precio. esto se solucionaria con un box plot para ver cuantos outliers

# %%
sns.boxplot(data = df['price'], color="lightblue")
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# #### con este diagrama podemos ver que hay muchos outliers. podemos comprobar que todo se agrupa en precios bajos.

# %%
df.dtypes
# Out:
# uid                    int64
# asin                  object
# title                 object
# stars                float64
# reviews                int64
# price                float64
# isBestSeller            bool
# boughtInLastMonth      int64
# category              object
# dtype: object

# %%
frequency_table3 = df['stars'].value_counts()
frequency_table3
# Out:
# stars
# 0.0    1225641
# 4.5     151577
# 4.6     136995
# 4.4     136165
# 5.0     128492
# 4.3     112564
# 4.7      94566
# 4.2      86871
# 4.0      66089
# 4.1      65115
# 4.8      41858
# 3.9      36555
# 3.8      27876
# 3.7      21137
# 3.6      16219
# 3.5      14673
# 3.0      12819
# 4.9      11081
# 3.4      10355
# 1.0       8484
# 3.3       8269
# 3.2       5771
# 3.1       4679
# 2.0       3901
# 2.9       3341
# 2.8       2306
# 2.7       2104
# 2.5       2103
# 2.6       1579
# 2.4       1060
# 2.3        734
# 2.2        602
# 2.1        540
# 1.5        404
# 1.9        300
# 1.8        249
# 1.7        177
# 1.4        149
# 1.6        147
# 1.3         78
# 1.2         23
# 1.1          3
# Name: count, dtype: int64

# %%
df["stars"].unique()
# Out:
# array([4.7, 4.6, 4.5, 4.8, 0. , 4.4, 4.3, 4.1, 4.9, 5. , 3.8, 3.6, 4. ,
#        4.2, 3. , 3.9, 2.5, 3.4, 3.7, 3.2, 3.3, 3.5, 2.7, 2.1, 1. , 3.1,
#        2. , 2.9, 2.8, 1.5, 2.2, 2.3, 2.6, 2.4, 1.4, 1.9, 1.8, 1.7, 1.6,
#        1.2, 1.3, 1.1])

# %%
mean_rating = df['stars'].mean()
mean_rating
# Out:
# np.float64(2.152836472966066)

# %%
median_rating = df['stars'].median()
median_rating
# Out:
# np.float64(0.0)

# %%
mode_rating = df['stars'].mode()[0]
mode_rating
# Out:
# np.float64(0.0)

# %% [markdown]
# #### suelen no valorar los productos

# %%
variance_start = df['stars'].var()
std_dev_start = df['stars'].std()

variance_price, std_dev_price
# Out:
# (np.float64(119445.48532254901), np.float64(2.194865378513421))

# %% [markdown]
# Hay variacion en las opiniones de los clientes

# %%
skewness_star = df['stars'].skew()
kurtosis_star = df['stars'].kurtosis()

skewness_star, kurtosis_star
# Out:
# (np.float64(0.08120735761080881), np.float64(-1.9260061280432994))

# %% [markdown]
# Se distribuyen en valores altos o bajos.

# %%
sns.histplot(df['stars'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='stars', ylabel='Count'>
